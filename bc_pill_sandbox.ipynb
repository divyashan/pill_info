# %%
import pickle

with open('./data/progestin.pickle', 'rb') as handle:
    name_progestin_map = pickle.load(handle)

with open('./data/generics.pickle', 'rb') as handle:
    name_generic_name_map = pickle.load(handle)

with open('./data/alternates.pickle', 'rb') as handle:
    name_alternates_map = pickle.load(handle)

# %% [markdown]
# ###

# %%
# name_progestin_map = Maps lower-case commercial name of birth control name to the active progestin 
# name_generic_name_map = Maps lower-case commercial name of birth control to generic name
# name_alternates_map = Maps lower-case commercial name of birth control to alternate medication; this lets you infer
# Out:
# {'': 'norethindrone',
#  '...show all 10 brand names': 'norgestrel',
#  '...show all 16 brand names': 'norethindrone',
#  '...show all 25 brand names': 'desogestrel',
#  'afirmelle': 'levonorgestrel',
#  'altavera': 'levonorgestrel',
#  'alyacen 1/35': 'norethindrone',
#  'alyacen 7/7/7': 'norethindrone',
#  'amethia': 'levonorgestrel',
#  'amethia (extended-cycle)': 'levonorgestrel',
#  'amethia lo': 'levonorgestrel',
#  'amethia lo (extended-cycle)': 'levonorgestrel',
#  'amethyst': 'levonorgestrel',
#  'and ferrous fumarate': 'norethindrone',
#  'and levomefolate': 'drospirenone',
#  'and levonorgestrel': 'levonorgestrel',
#  'apri': 'desogestrel',
#  'aranelle': 'norethindrone',
#  'ashlyna': 'levonorgestrel',
#  'aubra': 'levonorgestrel',
#  'aubra eq': 'levonorgestrel',
#  'aurovela 1.5/30': 'norethindrone',
#  'aurovela 1/20': 'norethindrone',
#  'aurovela 24 fe': 'norethindrone',
#  'aurovela fe 1.5/30': 'norethindrone',
#  'aurovela fe 1/20': 'norethindrone',
# ...
